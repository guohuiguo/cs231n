# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = 'cs231n/assignments/assignment1/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd /content/drive/My\ Drive/$FOLDERNAME/cs231n/datasets/
# !bash get_datasets.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/cs231n/assignments/assignment1/cs231n/datasets
# /content/drive/My Drive/cs231n/assignments/assignment1

# %% [markdown]
# # Softmax Classifier exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# In this exercise you will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier.
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** using numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
# Run some setup code for this notebook.
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10  #数据库
import matplotlib.pyplot as plt

# This is a bit of magic to make matplotlib figures appear inline in the
# notebook rather than in a new window.
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## CIFAR-10 Data Loading and Preprocessing

# %%
# Load the raw CIFAR-10 data.
cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

# Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
try:
   del X_train, y_train
   del X_test, y_test
   print('Clear previously loaded data.')
except:
   pass

X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

# As a sanity check, we print out the size of the training and test data.
print('Training data shape: ', X_train.shape)
print('Training labels shape: ', y_train.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Clear previously loaded data.
# Training data shape:  (50000, 32, 32, 3)
# Training labels shape:  (50000,)
# Test data shape:  (10000, 32, 32, 3)
# Test labels shape:  (10000,)

# %%
# Visualize some examples from the dataset.
# We show a few examples of training images from each class.
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
num_classes = len(classes)
samples_per_class = 7
for y, cls in enumerate(classes):
    idxs = np.flatnonzero(y_train == y)
    idxs = np.random.choice(idxs, samples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + y + 1
        plt.subplot(samples_per_class, num_classes, plt_idx)
        plt.imshow(X_train[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls)
plt.show()

# %%
# Split the data into train, val, and test sets. In addition we will
# create a small development set as a subset of the training data;
# we can use this for development so our code runs faster.
num_training = 49000  #将X_train 分割为两份，49000用来train的，1000用来做validation检验的
num_validation = 1000
num_test = 1000
num_dev = 500

# Our validation set will be num_validation points from the original
# training set.
mask = range(num_training, num_training + num_validation) #49000-50000为valid
X_val = X_train[mask]
y_val = y_train[mask]

# Our training set will be the first num_train points from the original
# training set.
mask = range(num_training) #0-49000为train
X_train = X_train[mask]
y_train = y_train[mask]

# We will also make a development set, which is a small subset of
# the training set.
mask = np.random.choice(num_training, num_dev, replace=False)
X_dev = X_train[mask] #开发集，从训练子集（前49000个元素的那个训练集）中随机得去寻找500个作为开发集
y_dev = y_train[mask]

# We use the first num_test points of the original test set as our
# test set.
mask = range(num_test) #取所有的10000个test中的前1000个作为所有的test
X_test = X_test[mask]
y_test = y_test[mask]

print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %%
# Preprocessing: reshape the image data into rows
X_train = np.reshape(X_train, (X_train.shape[0], -1)) #将后面的37 37 3乘在一起，变成一个二维矩阵！
X_val = np.reshape(X_val, (X_val.shape[0], -1))
X_test = np.reshape(X_test, (X_test.shape[0], -1))
X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))

# As a sanity check, print out the shapes of the data
print('Training data shape: ', X_train.shape)
print('Validation data shape: ', X_val.shape)
print('Test data shape: ', X_test.shape)
print('dev data shape: ', X_dev.shape)
# Out:
# Training data shape:  (50000, 3072)
# Validation data shape:  (1000, 3073)
# Test data shape:  (10000, 3072)
# dev data shape:  (500, 3073)

# %%
# Preprocessing: subtract the mean image
# first: compute the image mean based on the training data
mean_image = np.mean(X_train, axis=0) #行压缩求矩阵的每一列的平均值
print(mean_image[:10]) # print a few of the elements
plt.figure(figsize=(4,4))
plt.imshow(mean_image.reshape((32,32,3)).astype('uint8')) # visualize the mean image
plt.show()

# second: subtract the mean image from train and test data
X_train -= mean_image
X_val -= mean_image
X_test -= mean_image
X_dev -= mean_image

# third: append the bias dimension of ones (i.e. bias trick) so that our classifier
# only has to worry about optimizing a single weight matrix W.
X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))]) #将多个数组沿水平方向（即第二个轴，axis=1）堆叠在一起。要求这些数组在除了第二个轴以外的其他轴上的维度必须相同。
X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))]) #后面添加的一列1方便与W中新加入的一列b（上下进行位移的）进行想乘。
X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])

print(X_train.shape, X_val.shape, X_test.shape, X_dev.shape)
# Out:
# [130.64189796 135.98173469 132.47391837 130.05569388 135.34804082
#  131.75402041 130.96055102 136.14328571 132.47636735 131.48467347]
# (49000, 3073) (1000, 3073) (1000, 3073) (500, 3073)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside `cs231n/classifiers/softmax.py`.
#
# As you can see, we have prefilled the function `softmax_loss_naive` which uses for loops to evaluate the softmax loss function.

# %%
# Evaluate the naive implementation of the loss we provided for you:
from cs231n.classifiers.softmax import softmax_loss_naive
import time

# generate a random Softmax classifier weight matrix of small numbers
W = np.random.randn(3073, 10) * 0.0001

loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
print('loss: %f' % (loss, ))

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.383792
# loss: 2.383792
# sanity check: 2.302585

# %% [markdown]
# **Inline Question 1**
#
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# $\color{blue}{\textit Your Answer:}$ *Fill this in*
# 我的答案：loss其实是所有的loss_i 求平均再加上一个关于W的正则化。但是我们看到：W = np.random.randn(3073, 10) * 0.0001，w中的每个元素都很小，并且reg的取值为0.000005，也很小。所以正则化的影响就忽略掉了。
# 再观察p，实际上loss_i = log(exp(s_y_i)/sum(exp(s_j)))，因为s_j总共有10个（class的数量为10）假如我们的exp(s_y_i)的值比较均匀，则其比例就为0.1，-log一下就为-log(0.1),那么再去mean的话也为 -log(0.1)大小左右的值了。

# %% [markdown]
# The `grad` returned from the function above is right now all zero. Derive and implement the gradient for the softmax loss function and implement it inline inside the function `softmax_loss_naive`. You will find it helpful to interleave your new code inside the existing function.
#
# To check that you have correctly implemented the gradient, you can numerically estimate the gradient of the loss function and compare the numeric estimate to the gradient that you computed. We have provided code that does this for you:

# %%
# Once you've implemented the gradient, recompute it with the code below
# and gradient check it with the function we provided for you

# Compute the loss and its gradient at W.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# Numerically compute the gradient along several randomly chosen dimensions, and
# compare them with your analytically computed gradient. The numbers should match
# almost exactly along all dimensions.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad)

# do the gradient check once again with regularization turned on
# you didn't forget the regularization gradient did you?
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad)
# Out:
# numerical: 3.584978 analytic: 3.584978, relative error: 5.938133e-09
# numerical: -0.083336 analytic: -0.083336, relative error: 1.743276e-07
# numerical: -3.044787 analytic: -3.044787, relative error: 5.209156e-09
# numerical: 2.606644 analytic: 2.606644, relative error: 4.613007e-10
# numerical: 3.087595 analytic: 3.087594, relative error: 7.295322e-09
# numerical: 1.521238 analytic: 1.521238, relative error: 4.342963e-08
# numerical: -1.920518 analytic: -1.920518, relative error: 1.690349e-08
# numerical: 0.369035 analytic: 0.369035, relative error: 5.808267e-08
# numerical: 0.899205 analytic: 0.899205, relative error: 2.835652e-08
# numerical: 0.406025 analytic: 0.406025, relative error: 6.199270e-08
# numerical: -0.111041 analytic: -0.111041, relative error: 1.715439e-07
# numerical: 0.983718 analytic: 0.983718, relative error: 1.371917e-08
# numerical: 1.117823 analytic: 1.117823, relative error: 4.501328e-08
# numerical: -6.959888 analytic: -6.959888, relative error: 5.711384e-09
# numerical: -1.354327 analytic: -1.354327, relative error: 2.417151e-08
# numerical: -0.206150 analytic: -0.206150, relative error: 1.271168e-07
# numerical: 0.644664 analytic: 0.644664, relative error: 2.614640e-08
# numerical: -1.608391 analytic: -1.608391, relative error: 1.837828e-09
# numerical: -1.822795 analytic: -1.822795, relative error: 2.143008e-08
# numerical: -2.968697 analytic: -2.968697, relative error: 1.709238e-08

# %% [markdown]
# **Inline Question 2**
#
# Although gradcheck is reliable softmax loss, it is possible that for SVM loss, once in a while, a dimension in the gradcheck will not match exactly. What could such a discrepancy be caused by? Is it a reason for concern? What is a simple example in one dimension where a svm loss gradient check could fail? How would change the margin affect of the frequency of this happening?
#
# Note that SVM loss for a sample $(x_i, y_i)$ is defined as: $$L_i = \sum_{j\ne y_i}\max(0, s_j - s_{y_i} + \Delta)$$ where $j$ iterates over all classes except the correct class $y_i$ and $s_j$ denotes the classifier score for $j^{th}$ class. $\Delta$ is a scalar margin. For more information, refer to 'Multiclass Support Vector Machine loss' on [this](https://cs231n.github.io/linear-classify/) page.
#
# *Hint: the SVM loss function is not strictly speaking differentiable.*
#
#
# $\color{blue}{\textit Your Answer:}$ *fill this in.*
#
# 考虑在 $s_2 - s_1 + \Delta = 0$  的点（例如 \( s_1 = 0 \), \( s_2 = -\Delta \))：
#
# 解析梯度：按照次梯度，我们可以取 \([0, 1]\) 区间内的值（取决于定义），在不可微点没有单一的梯度。
#
# 数值梯度：通过小扰动 h 计算，对于函数 $ L = \max(0, (s_2 + h) - s_1 + \Delta) $ ：
# \[
# L = \max(0, (-\Delta + h) - 0 + \Delta) = \max(0, h)
# \]
# 分情况讨论：
# \begin{itemize}
#   \item 当 \( h > 0 \) 时，\( L = h \)，梯度为 \( 1 \)
#   \item 当 \( h < 0 \) 时，\( L = 0 \)，梯度为 \( 0 \)
# \end{itemize}
# 因此，数值梯度取决于扰动 \( h \) 的符号：
# \[
# \nabla_{\text{num}} =
# \begin{cases}
#   1 & \text{若 } h > 0 \\
#   0 & \text{若 } h < 0
# \end{cases}
# \]
# 这导致数值梯度不唯一，结果依赖于扰动方向。
# 所以问题就出在$s_2 - s_1 + \Delta = 0$ 点。
# 去分析，假如我们看单个点（s_y_i, s_j） 看成一个二元函数
# $ f(s_{y_i}, s_j) = \max(0, (s_j - s_{y_i} + Δ)$
# 所以整个就是一个平面，特殊情况就是一个直线，所以发生的概率几乎为0.而求 $Δ$ 的增大只是将直线的位置移动，不会对概率造成影响（实际上要用数学分析的知识严格推导才行，我这个只是直观上看是不变的）

# %%
# Next implement the function softmax_loss_vectorized; for now only compute the loss;
# we will implement the gradient in a moment.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('Naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, _ = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('Vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# The losses should match but your vectorized implementation should be much faster.
print('difference: %f' % (loss_naive - loss_vectorized))
# Out:
# Naive loss: 2.383792e+00 computed in 0.117787s
# Vectorized loss: 2.383792e+00 computed in 0.018864s
# difference: -0.000000

# %%
# Complete the implementation of softmax_loss_vectorized, and compute the gradient
# of the loss function in a vectorized way.

# The naive implementation and the vectorized implementation should match, but
# the vectorized version should still be much faster.
tic = time.time()
_, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('Naive loss and gradient: computed in %fs' % (toc - tic))

tic = time.time()
_, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('Vectorized loss and gradient: computed in %fs' % (toc - tic))

# The loss is a single number, so it is easy to compare the values computed
# by the two implementations. The gradient on the other hand is a matrix, so
# we use the Frobenius norm to compare them.
difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('difference: %f' % difference)
# Out:
# Naive loss and gradient: computed in 0.101663s
# Vectorized loss and gradient: computed in 0.012805s
# difference: 0.000000

# %% [markdown]
# ### Stochastic Gradient Descent
#
# We now have vectorized and efficient expressions for the loss, the gradient and our gradient matches the numerical gradient. We are therefore ready to do SGD to minimize the loss. Your code for this part will be written inside `cs231n/classifiers/linear_classifier.py`.

# %%
# In the file linear_classifier.py, implement SGD in the function
# LinearClassifier.train() and then run it with the code below.
from cs231n.classifiers import Softmax  # 导入softmax python文件
softmax = Softmax()
tic = time.time()
loss_hist = softmax.train(X_train, y_train, learning_rate=1e-7, reg=2.5e4,
                      num_iters=1500, verbose=True)
toc = time.time()
print('That took %fs' % (toc - tic))
# Out:
# iteration 0 / 1500: loss 764.777670
# iteration 100 / 1500: loss 280.453471
# iteration 200 / 1500: loss 103.620467
# iteration 300 / 1500: loss 39.285962
# iteration 400 / 1500: loss 15.724229
# iteration 500 / 1500: loss 7.114899
# iteration 600 / 1500: loss 3.906679
# iteration 700 / 1500: loss 2.798349
# iteration 800 / 1500: loss 2.283762
# iteration 900 / 1500: loss 2.185856
# iteration 1000 / 1500: loss 2.146358
# iteration 1100 / 1500: loss 2.159498
# iteration 1200 / 1500: loss 2.126230
# iteration 1300 / 1500: loss 2.074778
# iteration 1400 / 1500: loss 2.102681
# That took 11.920342s

# %%
# A useful debugging strategy is to plot the loss as a function of
# iteration number:
plt.plot(loss_hist)
plt.xlabel('Iteration number')
plt.ylabel('Loss value')
plt.show()

# %%
# Write the LinearClassifier.predict function and evaluate the performance on
# both the training and validation set
# You should get validation accuracy of about 0.34 (> 0.33).
y_train_pred = softmax.predict(X_train)
print('training accuracy: %f' % (np.mean(y_train == y_train_pred), ))
y_val_pred = softmax.predict(X_val)
print('validation accuracy: %f' % (np.mean(y_val == y_val_pred), ))
# Out:
# training accuracy: 0.330184
# validation accuracy: 0.342000

# %%
# Save the trained model for autograder.
softmax.save("softmax.npy")
# Out:
# softmax.npy saved.

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of about 0.365 (> 0.36) on the validation set.

# Note: you may see runtime/overflow warnings during hyper-parameter search.
# This may be caused by extreme values, and is not a bug.

# results is dictionary mapping tuples of the form
# (learning_rate, regularization_strength) to tuples of the form
# (training_accuracy, validation_accuracy). The accuracy is simply the fraction
# of data points that are correctly classified.
import copy
results = {}
best_val = -1   # The highest validation accuracy that we have seen so far.
best_softmax = None # The Softmax object that achieved the highest validation rate.

################################################################################
# TODO:                                                                        #
# Write code that chooses the best hyperparameters by tuning on the validation #
# set. For each combination of hyperparameters, train a Softmax on the.        #
# training set, compute its accuracy on the training and validation sets, and  #
# store these numbers in the results dictionary. In addition, store the best   #
# validation accuracy in best_val and the Softmax object that achieves this.   #
# accuracy in best_softmax.                                                    #
#                                                                              #
# Hint: You should use a small value for num_iters as you develop your         #
# validation code so that the classifiers don't take much time to train; once  #
# you are confident that your validation code works, you should rerun the      #
# code with a larger value for num_iters.                                      #
################################################################################

# Provided as a reference. You may or may not want to change these hyperparameters
learning_rates = [1e-7, 1e-6]
regularization_strengths = [2.5e4, 1e4]
lr_values = np.arange(learning_rates[0],
                     learning_rates[1] + 1e-8,  # 加微小值确保包含右边界
                     1e-7)
reg_values = np.arange(regularization_strengths[0],
                      regularization_strengths[1] - 1e-3,  # 减微小值确保包含右边界
                      -1e3)
for lr_new in lr_values:
  for reg_new in  reg_values:
    softmax = Softmax()  # 每次循环新建模型
    loss_hist_new = softmax.train(X_train, y_train, learning_rate=lr_new, reg=reg_new, num_iters=200, verbose=True)
    y_train_pred = softmax.predict(X_train)
    tr_acc = np.mean(y_train == y_train_pred)
    print('training accuracy: %f' % (tr_acc, ))
    y_val_pred = softmax.predict(X_val)
    valid_acc = np.mean(y_val == y_val_pred)
    print('validation accuracy: %f' % (valid_acc, ))
    results[(lr_new,reg_new)] = (tr_acc, valid_acc)

    if valid_acc > best_val:
            best_val = valid_acc
            best_softmax = copy.deepcopy(softmax)  # 深拷贝保存最佳模型


# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))

print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 200: loss 775.958921
# iteration 100 / 200: loss 284.940795
# training accuracy: 0.206265
# validation accuracy: 0.204000
# iteration 0 / 200: loss 749.054788
# iteration 100 / 200: loss 286.220628
# training accuracy: 0.204592
# validation accuracy: 0.226000
# iteration 0 / 200: loss 715.609824
# iteration 100 / 200: loss 284.617537
# training accuracy: 0.204102
# validation accuracy: 0.215000
# iteration 0 / 200: loss 694.958549
# iteration 100 / 200: loss 287.690592
# training accuracy: 0.178980
# validation accuracy: 0.145000
# iteration 0 / 200: loss 645.324097
# iteration 100 / 200: loss 277.623497
# training accuracy: 0.192469
# validation accuracy: 0.190000
# iteration 0 / 200: loss 618.047712
# iteration 100 / 200: loss 277.034732
# training accuracy: 0.178694
# validation accuracy: 0.200000
# iteration 0 / 200: loss 584.653476
# iteration 100 / 200: loss 272.885302
# training accuracy: 0.184816
# validation accuracy: 0.194000
# iteration 0 / 200: loss 553.515780
# iteration 100 / 200: loss 268.559197
# training accuracy: 0.195796
# validation accuracy: 0.210000
# iteration 0 / 200: loss 525.346955
# iteration 100 / 200: loss 265.464018
# training accuracy: 0.197959
# validation accuracy: 0.209000
# iteration 0 / 200: loss 500.858575
# iteration 100 / 200: loss 263.694662
# training accuracy: 0.195816
# validation accuracy: 0.201000
# iteration 0 / 200: loss 467.970004
# iteration 100 / 200: loss 255.489872
# training accuracy: 0.179857
# validation accuracy: 0.197000
# iteration 0 / 200: loss 435.668955
# iteration 100 / 200: loss 248.144635
# training accuracy: 0.186735
# validation accuracy: 0.187000
# iteration 0 / 200: loss 403.872255
# iteration 100 / 200: loss 239.329242
# training accuracy: 0.166000
# validation accuracy: 0.164000
# iteration 0 / 200: loss 371.398042
# iteration 100 / 200: loss 229.149701
# training accuracy: 0.182653
# validation accuracy: 0.181000
# iteration 0 / 200: loss 349.020839
# iteration 100 / 200: loss 223.517476
# training accuracy: 0.173816
# validation accuracy: 0.198000
# iteration 0 / 200: loss 309.095988
# iteration 100 / 200: loss 206.302314
# training accuracy: 0.169755
# validation accuracy: 0.154000
# iteration 0 / 200: loss 773.044163
# iteration 100 / 200: loss 104.587216
# training accuracy: 0.283469
# validation accuracy: 0.292000
# iteration 0 / 200: loss 743.311738
# iteration 100 / 200: loss 109.044905
# training accuracy: 0.282082
# validation accuracy: 0.289000
# iteration 0 / 200: loss 705.217034
# iteration 100 / 200: loss 111.846770
# training accuracy: 0.276184
# validation accuracy: 0.291000
# iteration 0 / 200: loss 673.986919
# iteration 100 / 200: loss 115.817157
# training accuracy: 0.277837
# validation accuracy: 0.283000
# iteration 0 / 200: loss 649.644990
# iteration 100 / 200: loss 121.228235
# training accuracy: 0.276939
# validation accuracy: 0.284000
# iteration 0 / 200: loss 618.956006
# iteration 100 / 200: loss 124.757053
# training accuracy: 0.272939
# validation accuracy: 0.280000
# iteration 0 / 200: loss 581.689164
# iteration 100 / 200: loss 126.897236
# training accuracy: 0.262265
# validation accuracy: 0.261000
# iteration 0 / 200: loss 554.609257
# iteration 100 / 200: loss 131.055207
# training accuracy: 0.256571
# validation accuracy: 0.288000
# iteration 0 / 200: loss 523.434279
# iteration 100 / 200: loss 134.393819
# training accuracy: 0.254082
# validation accuracy: 0.278000
# iteration 0 / 200: loss 491.832110
# iteration 100 / 200: loss 136.584142
# training accuracy: 0.250837
# validation accuracy: 0.265000
# iteration 0 / 200: loss 466.011242
# iteration 100 / 200: loss 140.254428
# training accuracy: 0.259612
# validation accuracy: 0.266000
# iteration 0 / 200: loss 435.566711
# iteration 100 / 200: loss 141.605137
# training accuracy: 0.231265
# validation accuracy: 0.245000
# iteration 0 / 200: loss 408.047414
# iteration 100 / 200: loss 143.734515
# training accuracy: 0.239510
# validation accuracy: 0.228000
# iteration 0 / 200: loss 380.854428
# iteration 100 / 200: loss 145.581710
# training accuracy: 0.236163
# validation accuracy: 0.244000
# iteration 0 / 200: loss 339.870558
# iteration 100 / 200: loss 140.202582
# training accuracy: 0.239857
# validation accuracy: 0.242000
# iteration 0 / 200: loss 313.524931
# iteration 100 / 200: loss 140.265821
# training accuracy: 0.230918
# validation accuracy: 0.248000
# iteration 0 / 200: loss 770.513314
# iteration 100 / 200: loss 39.086270
# training accuracy: 0.319673
# validation accuracy: 0.333000
# iteration 0 / 200: loss 736.851887
# iteration 100 / 200: loss 42.100546
# training accuracy: 0.319102
# validation accuracy: 0.339000
# iteration 0 / 200: loss 712.260189
# iteration 100 / 200: loss 45.819376
# training accuracy: 0.322735
# validation accuracy: 0.331000
# iteration 0 / 200: loss 679.411763
# iteration 100 / 200: loss 49.148323
# training accuracy: 0.320633
# validation accuracy: 0.322000
# iteration 0 / 200: loss 643.192994
# iteration 100 / 200: loss 52.245807
# training accuracy: 0.309571
# validation accuracy: 0.313000
# iteration 0 / 200: loss 631.019515
# iteration 100 / 200: loss 57.758140
# training accuracy: 0.310245
# validation accuracy: 0.335000
# iteration 0 / 200: loss 583.778504
# iteration 100 / 200: loss 60.224827
# training accuracy: 0.307388
# validation accuracy: 0.315000
# iteration 0 / 200: loss 556.638313
# iteration 100 / 200: loss 64.561090
# training accuracy: 0.307429
# validation accuracy: 0.305000
# iteration 0 / 200: loss 521.847003
# iteration 100 / 200: loss 68.327950
# training accuracy: 0.304408
# validation accuracy: 0.320000
# iteration 0 / 200: loss 496.900940
# iteration 100 / 200: loss 73.344530
# training accuracy: 0.305429
# validation accuracy: 0.314000
# iteration 0 / 200: loss 464.705870
# iteration 100 / 200: loss 77.068930
# training accuracy: 0.295449
# validation accuracy: 0.321000
# iteration 0 / 200: loss 435.175148
# iteration 100 / 200: loss 81.253269
# training accuracy: 0.294510
# validation accuracy: 0.324000
# iteration 0 / 200: loss 403.767230
# iteration 100 / 200: loss 84.905289
# training accuracy: 0.287143
# validation accuracy: 0.297000
# iteration 0 / 200: loss 369.977359
# iteration 100 / 200: loss 87.614674
# training accuracy: 0.280796
# validation accuracy: 0.273000
# iteration 0 / 200: loss 345.407144
# iteration 100 / 200: loss 92.087867
# training accuracy: 0.276327
# validation accuracy: 0.258000
# iteration 0 / 200: loss 313.419979
# iteration 100 / 200: loss 94.323682
# training accuracy: 0.271020
# validation accuracy: 0.260000
# iteration 0 / 200: loss 769.953795
# iteration 100 / 200: loss 15.441071
# training accuracy: 0.328429
# validation accuracy: 0.336000
# iteration 0 / 200: loss 750.056119
# iteration 100 / 200: loss 17.386155
# training accuracy: 0.336531
# validation accuracy: 0.341000
# iteration 0 / 200: loss 708.688952
# iteration 100 / 200: loss 19.018324
# training accuracy: 0.323265
# validation accuracy: 0.347000
# iteration 0 / 200: loss 676.704609
# iteration 100 / 200: loss 21.207944
# training accuracy: 0.328510
# validation accuracy: 0.345000
# iteration 0 / 200: loss 636.955522
# iteration 100 / 200: loss 23.251857
# training accuracy: 0.330122
# validation accuracy: 0.347000
# iteration 0 / 200: loss 613.192847
# iteration 100 / 200: loss 26.040597
# training accuracy: 0.322265
# validation accuracy: 0.333000
# iteration 0 / 200: loss 583.742907
# iteration 100 / 200: loss 28.799878
# training accuracy: 0.328633
# validation accuracy: 0.332000
# iteration 0 / 200: loss 562.124354
# iteration 100 / 200: loss 32.383947
# training accuracy: 0.316551
# validation accuracy: 0.330000
# iteration 0 / 200: loss 524.726147
# iteration 100 / 200: loss 35.496918
# training accuracy: 0.331102
# validation accuracy: 0.347000
# iteration 0 / 200: loss 497.459163
# iteration 100 / 200: loss 39.217954
# training accuracy: 0.330633
# validation accuracy: 0.347000
# iteration 0 / 200: loss 469.572584
# iteration 100 / 200: loss 43.196816
# training accuracy: 0.323041
# validation accuracy: 0.337000
# iteration 0 / 200: loss 442.132176
# iteration 100 / 200: loss 47.413533
# training accuracy: 0.327082
# validation accuracy: 0.321000
# iteration 0 / 200: loss 400.926161
# iteration 100 / 200: loss 50.482296
# training accuracy: 0.318571
# validation accuracy: 0.330000
# iteration 0 / 200: loss 374.305619
# iteration 100 / 200: loss 55.390502
# training accuracy: 0.318612
# validation accuracy: 0.326000
# iteration 0 / 200: loss 343.261301
# iteration 100 / 200: loss 59.429091
# training accuracy: 0.308265
# validation accuracy: 0.316000
# iteration 0 / 200: loss 313.788968
# iteration 100 / 200: loss 63.922530
# training accuracy: 0.309245
# validation accuracy: 0.305000
# iteration 0 / 200: loss 763.956833
# iteration 100 / 200: loss 6.843059
# training accuracy: 0.321980
# validation accuracy: 0.342000
# iteration 0 / 200: loss 748.022651
# iteration 100 / 200: loss 7.827252
# training accuracy: 0.336367
# validation accuracy: 0.353000
# iteration 0 / 200: loss 720.089792
# iteration 100 / 200: loss 8.840880
# training accuracy: 0.324653
# validation accuracy: 0.338000
# iteration 0 / 200: loss 681.447103
# iteration 100 / 200: loss 9.902333
# training accuracy: 0.327327
# validation accuracy: 0.344000
# iteration 0 / 200: loss 649.526981
# iteration 100 / 200: loss 11.295537
# training accuracy: 0.329490
# validation accuracy: 0.339000
# iteration 0 / 200: loss 623.823441
# iteration 100 / 200: loss 12.808749
# training accuracy: 0.330980
# validation accuracy: 0.344000
# iteration 0 / 200: loss 589.529924
# iteration 100 / 200: loss 14.625807
# training accuracy: 0.332469
# validation accuracy: 0.348000
# iteration 0 / 200: loss 562.699238
# iteration 100 / 200: loss 16.628607
# training accuracy: 0.336980
# validation accuracy: 0.343000
# iteration 0 / 200: loss 527.068608
# iteration 100 / 200: loss 18.800774
# training accuracy: 0.335796
# validation accuracy: 0.346000
# iteration 0 / 200: loss 502.594780
# iteration 100 / 200: loss 21.647640
# training accuracy: 0.333061
# validation accuracy: 0.338000
# iteration 0 / 200: loss 464.762950
# iteration 100 / 200: loss 24.229756
# training accuracy: 0.332143
# validation accuracy: 0.341000
# iteration 0 / 200: loss 436.756431
# iteration 100 / 200: loss 27.547849
# training accuracy: 0.333367
# validation accuracy: 0.341000
# iteration 0 / 200: loss 401.389141
# iteration 100 / 200: loss 30.722116
# training accuracy: 0.335694
# validation accuracy: 0.351000
# iteration 0 / 200: loss 377.510184
# iteration 100 / 200: loss 35.100700
# training accuracy: 0.335082
# validation accuracy: 0.340000
# iteration 0 / 200: loss 342.080289
# iteration 100 / 200: loss 38.706435
# training accuracy: 0.335755
# validation accuracy: 0.350000
# iteration 0 / 200: loss 310.317819
# iteration 100 / 200: loss 42.598417
# training accuracy: 0.324306
# validation accuracy: 0.341000
# iteration 0 / 200: loss 772.733636
# iteration 100 / 200: loss 3.780210
# training accuracy: 0.328184
# validation accuracy: 0.354000
# iteration 0 / 200: loss 727.913708
# iteration 100 / 200: loss 4.140705
# training accuracy: 0.328429
# validation accuracy: 0.337000
# iteration 0 / 200: loss 704.747173
# iteration 100 / 200: loss 4.702883
# training accuracy: 0.336939
# validation accuracy: 0.351000
# iteration 0 / 200: loss 681.875324
# iteration 100 / 200: loss 5.248935
# training accuracy: 0.329469
# validation accuracy: 0.344000
# iteration 0 / 200: loss 647.258155
# iteration 100 / 200: loss 5.952383
# training accuracy: 0.324061
# validation accuracy: 0.337000
# iteration 0 / 200: loss 615.629289
# iteration 100 / 200: loss 6.744242
# training accuracy: 0.324551
# validation accuracy: 0.325000
# iteration 0 / 200: loss 585.566506
# iteration 100 / 200: loss 7.787588
# training accuracy: 0.331347
# validation accuracy: 0.357000
# iteration 0 / 200: loss 566.540597
# iteration 100 / 200: loss 9.069053
# training accuracy: 0.334612
# validation accuracy: 0.348000
# iteration 0 / 200: loss 532.313627
# iteration 100 / 200: loss 10.506235
# training accuracy: 0.337286
# validation accuracy: 0.364000
# iteration 0 / 200: loss 498.330092
# iteration 100 / 200: loss 12.062726
# training accuracy: 0.337755
# validation accuracy: 0.350000
# iteration 0 / 200: loss 470.311660
# iteration 100 / 200: loss 14.261275
# training accuracy: 0.344408
# validation accuracy: 0.355000
# iteration 0 / 200: loss 432.426679
# iteration 100 / 200: loss 16.248839
# training accuracy: 0.344878
# validation accuracy: 0.356000
# iteration 0 / 200: loss 404.324964
# iteration 100 / 200: loss 19.008884
# training accuracy: 0.333306
# validation accuracy: 0.327000
# iteration 0 / 200: loss 372.604019
# iteration 100 / 200: loss 22.123889
# training accuracy: 0.346204
# validation accuracy: 0.346000
# iteration 0 / 200: loss 344.360826
# iteration 100 / 200: loss 25.602145
# training accuracy: 0.337939
# validation accuracy: 0.359000
# iteration 0 / 200: loss 310.315730
# iteration 100 / 200: loss 29.199483
# training accuracy: 0.337673
# validation accuracy: 0.344000
# iteration 0 / 200: loss 764.973302
# iteration 100 / 200: loss 2.725978
# training accuracy: 0.320020
# validation accuracy: 0.321000
# iteration 0 / 200: loss 740.184641
# iteration 100 / 200: loss 2.917045
# training accuracy: 0.322837
# validation accuracy: 0.333000
# iteration 0 / 200: loss 714.885577
# iteration 100 / 200: loss 3.083181
# training accuracy: 0.320102
# validation accuracy: 0.342000
# iteration 0 / 200: loss 685.802747
# iteration 100 / 200: loss 3.369794
# training accuracy: 0.334204
# validation accuracy: 0.341000
# iteration 0 / 200: loss 654.888869
# iteration 100 / 200: loss 3.714184
# training accuracy: 0.335245
# validation accuracy: 0.350000
# iteration 0 / 200: loss 613.239521
# iteration 100 / 200: loss 4.168273
# training accuracy: 0.333612
# validation accuracy: 0.353000
# iteration 0 / 200: loss 585.407254
# iteration 100 / 200: loss 4.652533
# training accuracy: 0.330735
# validation accuracy: 0.346000
# iteration 0 / 200: loss 560.341297
# iteration 100 / 200: loss 5.428311
# training accuracy: 0.323204
# validation accuracy: 0.337000
# iteration 0 / 200: loss 529.870648
# iteration 100 / 200: loss 6.201122
# training accuracy: 0.341490
# validation accuracy: 0.355000
# iteration 0 / 200: loss 497.708334
# iteration 100 / 200: loss 7.251120
# training accuracy: 0.344245
# validation accuracy: 0.360000
# iteration 0 / 200: loss 473.030521
# iteration 100 / 200: loss 8.597562
# training accuracy: 0.341776
# validation accuracy: 0.356000
# iteration 0 / 200: loss 435.362045
# iteration 100 / 200: loss 10.203378
# training accuracy: 0.343694
# validation accuracy: 0.374000
# iteration 0 / 200: loss 405.505012
# iteration 100 / 200: loss 11.980832
# training accuracy: 0.348878
# validation accuracy: 0.358000
# iteration 0 / 200: loss 372.984929
# iteration 100 / 200: loss 14.275455
# training accuracy: 0.343102
# validation accuracy: 0.354000
# iteration 0 / 200: loss 344.451563
# iteration 100 / 200: loss 17.129441
# training accuracy: 0.334857
# validation accuracy: 0.365000
# iteration 0 / 200: loss 309.766301
# iteration 100 / 200: loss 19.898818
# training accuracy: 0.340061
# validation accuracy: 0.348000
# iteration 0 / 200: loss 774.129925
# iteration 100 / 200: loss 2.277674
# training accuracy: 0.326571
# validation accuracy: 0.337000
# iteration 0 / 200: loss 746.579118
# iteration 100 / 200: loss 2.412178
# training accuracy: 0.328653
# validation accuracy: 0.333000
# iteration 0 / 200: loss 713.403998
# iteration 100 / 200: loss 2.476662
# training accuracy: 0.318959
# validation accuracy: 0.331000
# iteration 0 / 200: loss 687.926143
# iteration 100 / 200: loss 2.578653
# training accuracy: 0.332102
# validation accuracy: 0.345000
# iteration 0 / 200: loss 645.333604
# iteration 100 / 200: loss 2.725407
# training accuracy: 0.327449
# validation accuracy: 0.332000
# iteration 0 / 200: loss 616.153484
# iteration 100 / 200: loss 2.937480
# training accuracy: 0.324102
# validation accuracy: 0.326000
# iteration 0 / 200: loss 586.945793
# iteration 100 / 200: loss 3.331952
# training accuracy: 0.337755
# validation accuracy: 0.344000
# iteration 0 / 200: loss 559.357409
# iteration 100 / 200: loss 3.604669
# training accuracy: 0.339898
# validation accuracy: 0.350000
# iteration 0 / 200: loss 523.789609
# iteration 100 / 200: loss 4.127035
# training accuracy: 0.341204
# validation accuracy: 0.351000
# iteration 0 / 200: loss 496.627754
# iteration 100 / 200: loss 4.829582
# training accuracy: 0.341143
# validation accuracy: 0.347000
# iteration 0 / 200: loss 461.197825
# iteration 100 / 200: loss 5.506940
# training accuracy: 0.329306
# validation accuracy: 0.343000
# iteration 0 / 200: loss 434.550924
# iteration 100 / 200: loss 6.593690
# training accuracy: 0.332286
# validation accuracy: 0.352000
# iteration 0 / 200: loss 406.160040
# iteration 100 / 200: loss 7.922493
# training accuracy: 0.337388
# validation accuracy: 0.364000
# iteration 0 / 200: loss 372.535424
# iteration 100 / 200: loss 9.505509
# training accuracy: 0.337510
# validation accuracy: 0.357000
# iteration 0 / 200: loss 347.553648
# iteration 100 / 200: loss 11.685260
# training accuracy: 0.354306
# validation accuracy: 0.364000
# iteration 0 / 200: loss 312.155007
# iteration 100 / 200: loss 14.029183
# training accuracy: 0.348592
# validation accuracy: 0.363000
# iteration 0 / 200: loss 772.786564
# iteration 100 / 200: loss 2.145732
# training accuracy: 0.324551
# validation accuracy: 0.332000
# iteration 0 / 200: loss 742.194410
# iteration 100 / 200: loss 2.238899
# training accuracy: 0.308837
# validation accuracy: 0.324000
# iteration 0 / 200: loss 715.223973
# iteration 100 / 200: loss 2.240899
# training accuracy: 0.319714
# validation accuracy: 0.329000
# iteration 0 / 200: loss 683.141210
# iteration 100 / 200: loss 2.241721
# training accuracy: 0.327918
# validation accuracy: 0.337000
# iteration 0 / 200: loss 657.445305
# iteration 100 / 200: loss 2.367301
# training accuracy: 0.337714
# validation accuracy: 0.339000
# iteration 0 / 200: loss 620.308334
# iteration 100 / 200: loss 2.406373
# training accuracy: 0.330837
# validation accuracy: 0.336000
# iteration 0 / 200: loss 593.235357
# iteration 100 / 200: loss 2.561350
# training accuracy: 0.336714
# validation accuracy: 0.347000
# iteration 0 / 200: loss 549.737982
# iteration 100 / 200: loss 2.824661
# training accuracy: 0.327796
# validation accuracy: 0.342000
# iteration 0 / 200: loss 520.743789
# iteration 100 / 200: loss 3.087600
# training accuracy: 0.337571
# validation accuracy: 0.356000
# iteration 0 / 200: loss 492.861079
# iteration 100 / 200: loss 3.488625
# training accuracy: 0.328388
# validation accuracy: 0.338000
# iteration 0 / 200: loss 468.939184
# iteration 100 / 200: loss 4.022999
# training accuracy: 0.334122
# validation accuracy: 0.347000
# iteration 0 / 200: loss 440.157427
# iteration 100 / 200: loss 4.635807
# training accuracy: 0.349531
# validation accuracy: 0.354000
# iteration 0 / 200: loss 408.208383
# iteration 100 / 200: loss 5.557701
# training accuracy: 0.344653
# validation accuracy: 0.363000
# iteration 0 / 200: loss 371.658003
# iteration 100 / 200: loss 6.736552
# training accuracy: 0.341980
# validation accuracy: 0.348000
# iteration 0 / 200: loss 341.121034
# iteration 100 / 200: loss 8.037543
# training accuracy: 0.344898
# validation accuracy: 0.348000
# iteration 0 / 200: loss 317.272741
# iteration 100 / 200: loss 10.096229
# training accuracy: 0.350571
# validation accuracy: 0.357000
# iteration 0 / 200: loss 773.463227
# iteration 100 / 200: loss 2.119632
# training accuracy: 0.317265
# validation accuracy: 0.336000
# iteration 0 / 200: loss 750.043170
# iteration 100 / 200: loss 2.128192
# training accuracy: 0.323592
# validation accuracy: 0.333000
# iteration 0 / 200: loss 713.177208
# iteration 100 / 200: loss 2.110822
# training accuracy: 0.310102
# validation accuracy: 0.334000
# iteration 0 / 200: loss 678.910225
# iteration 100 / 200: loss 2.186848
# training accuracy: 0.313327
# validation accuracy: 0.330000
# iteration 0 / 200: loss 643.418114
# iteration 100 / 200: loss 2.163733
# training accuracy: 0.326776
# validation accuracy: 0.332000
# iteration 0 / 200: loss 622.231843
# iteration 100 / 200: loss 2.283446
# training accuracy: 0.317796
# validation accuracy: 0.329000
# iteration 0 / 200: loss 589.039849
# iteration 100 / 200: loss 2.363446
# training accuracy: 0.329776
# validation accuracy: 0.332000
# iteration 0 / 200: loss 557.861814
# iteration 100 / 200: loss 2.426010
# training accuracy: 0.331959
# validation accuracy: 0.350000
# iteration 0 / 200: loss 528.218858
# iteration 100 / 200: loss 2.597621
# training accuracy: 0.326163
# validation accuracy: 0.329000
# iteration 0 / 200: loss 498.077482
# iteration 100 / 200: loss 2.851480
# training accuracy: 0.334551
# validation accuracy: 0.343000
# iteration 0 / 200: loss 467.019157
# iteration 100 / 200: loss 3.095488
# training accuracy: 0.344592
# validation accuracy: 0.356000
# iteration 0 / 200: loss 432.494135
# iteration 100 / 200: loss 3.427038
# training accuracy: 0.339204
# validation accuracy: 0.351000
# iteration 0 / 200: loss 406.348118
# iteration 100 / 200: loss 4.014536
# training accuracy: 0.342347
# validation accuracy: 0.352000
# iteration 0 / 200: loss 381.108489
# iteration 100 / 200: loss 4.846061
# training accuracy: 0.346020
# validation accuracy: 0.344000
# iteration 0 / 200: loss 341.897198
# iteration 100 / 200: loss 5.828956
# training accuracy: 0.349367
# validation accuracy: 0.356000
# iteration 0 / 200: loss 308.413905
# iteration 100 / 200: loss 7.292823
# training accuracy: 0.350796
# validation accuracy: 0.368000
# lr 1.000000e-07 reg 1.000000e+04 train accuracy: 0.169755 val accuracy: 0.154000
# lr 1.000000e-07 reg 1.100000e+04 train accuracy: 0.173816 val accuracy: 0.198000
# lr 1.000000e-07 reg 1.200000e+04 train accuracy: 0.182653 val accuracy: 0.181000
# lr 1.000000e-07 reg 1.300000e+04 train accuracy: 0.166000 val accuracy: 0.164000
# lr 1.000000e-07 reg 1.400000e+04 train accuracy: 0.186735 val accuracy: 0.187000
# lr 1.000000e-07 reg 1.500000e+04 train accuracy: 0.179857 val accuracy: 0.197000
# lr 1.000000e-07 reg 1.600000e+04 train accuracy: 0.195816 val accuracy: 0.201000
# lr 1.000000e-07 reg 1.700000e+04 train accuracy: 0.197959 val accuracy: 0.209000
# lr 1.000000e-07 reg 1.800000e+04 train accuracy: 0.195796 val accuracy: 0.210000
# lr 1.000000e-07 reg 1.900000e+04 train accuracy: 0.184816 val accuracy: 0.194000
# lr 1.000000e-07 reg 2.000000e+04 train accuracy: 0.178694 val accuracy: 0.200000
# lr 1.000000e-07 reg 2.100000e+04 train accuracy: 0.192469 val accuracy: 0.190000
# lr 1.000000e-07 reg 2.200000e+04 train accuracy: 0.178980 val accuracy: 0.145000
# lr 1.000000e-07 reg 2.300000e+04 train accuracy: 0.204102 val accuracy: 0.215000
# lr 1.000000e-07 reg 2.400000e+04 train accuracy: 0.204592 val accuracy: 0.226000
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.206265 val accuracy: 0.204000
# lr 2.000000e-07 reg 1.000000e+04 train accuracy: 0.230918 val accuracy: 0.248000
# lr 2.000000e-07 reg 1.100000e+04 train accuracy: 0.239857 val accuracy: 0.242000
# lr 2.000000e-07 reg 1.200000e+04 train accuracy: 0.236163 val accuracy: 0.244000
# lr 2.000000e-07 reg 1.300000e+04 train accuracy: 0.239510 val accuracy: 0.228000
# lr 2.000000e-07 reg 1.400000e+04 train accuracy: 0.231265 val accuracy: 0.245000
# lr 2.000000e-07 reg 1.500000e+04 train accuracy: 0.259612 val accuracy: 0.266000
# lr 2.000000e-07 reg 1.600000e+04 train accuracy: 0.250837 val accuracy: 0.265000
# lr 2.000000e-07 reg 1.700000e+04 train accuracy: 0.254082 val accuracy: 0.278000
# lr 2.000000e-07 reg 1.800000e+04 train accuracy: 0.256571 val accuracy: 0.288000
# lr 2.000000e-07 reg 1.900000e+04 train accuracy: 0.262265 val accuracy: 0.261000
# lr 2.000000e-07 reg 2.000000e+04 train accuracy: 0.272939 val accuracy: 0.280000
# lr 2.000000e-07 reg 2.100000e+04 train accuracy: 0.276939 val accuracy: 0.284000
# lr 2.000000e-07 reg 2.200000e+04 train accuracy: 0.277837 val accuracy: 0.283000
# lr 2.000000e-07 reg 2.300000e+04 train accuracy: 0.276184 val accuracy: 0.291000
# lr 2.000000e-07 reg 2.400000e+04 train accuracy: 0.282082 val accuracy: 0.289000
# lr 2.000000e-07 reg 2.500000e+04 train accuracy: 0.283469 val accuracy: 0.292000
# lr 3.000000e-07 reg 1.000000e+04 train accuracy: 0.271020 val accuracy: 0.260000
# lr 3.000000e-07 reg 1.100000e+04 train accuracy: 0.276327 val accuracy: 0.258000
# lr 3.000000e-07 reg 1.200000e+04 train accuracy: 0.280796 val accuracy: 0.273000
# lr 3.000000e-07 reg 1.300000e+04 train accuracy: 0.287143 val accuracy: 0.297000
# lr 3.000000e-07 reg 1.400000e+04 train accuracy: 0.294510 val accuracy: 0.324000
# lr 3.000000e-07 reg 1.500000e+04 train accuracy: 0.295449 val accuracy: 0.321000
# lr 3.000000e-07 reg 1.600000e+04 train accuracy: 0.305429 val accuracy: 0.314000
# lr 3.000000e-07 reg 1.700000e+04 train accuracy: 0.304408 val accuracy: 0.320000
# lr 3.000000e-07 reg 1.800000e+04 train accuracy: 0.307429 val accuracy: 0.305000
# lr 3.000000e-07 reg 1.900000e+04 train accuracy: 0.307388 val accuracy: 0.315000
# lr 3.000000e-07 reg 2.000000e+04 train accuracy: 0.310245 val accuracy: 0.335000
# lr 3.000000e-07 reg 2.100000e+04 train accuracy: 0.309571 val accuracy: 0.313000
# lr 3.000000e-07 reg 2.200000e+04 train accuracy: 0.320633 val accuracy: 0.322000
# lr 3.000000e-07 reg 2.300000e+04 train accuracy: 0.322735 val accuracy: 0.331000
# lr 3.000000e-07 reg 2.400000e+04 train accuracy: 0.319102 val accuracy: 0.339000
# lr 3.000000e-07 reg 2.500000e+04 train accuracy: 0.319673 val accuracy: 0.333000
# lr 4.000000e-07 reg 1.000000e+04 train accuracy: 0.309245 val accuracy: 0.305000
# lr 4.000000e-07 reg 1.100000e+04 train accuracy: 0.308265 val accuracy: 0.316000
# lr 4.000000e-07 reg 1.200000e+04 train accuracy: 0.318612 val accuracy: 0.326000
# lr 4.000000e-07 reg 1.300000e+04 train accuracy: 0.318571 val accuracy: 0.330000
# lr 4.000000e-07 reg 1.400000e+04 train accuracy: 0.327082 val accuracy: 0.321000
# lr 4.000000e-07 reg 1.500000e+04 train accuracy: 0.323041 val accuracy: 0.337000
# lr 4.000000e-07 reg 1.600000e+04 train accuracy: 0.330633 val accuracy: 0.347000
# lr 4.000000e-07 reg 1.700000e+04 train accuracy: 0.331102 val accuracy: 0.347000
# lr 4.000000e-07 reg 1.800000e+04 train accuracy: 0.316551 val accuracy: 0.330000
# lr 4.000000e-07 reg 1.900000e+04 train accuracy: 0.328633 val accuracy: 0.332000
# lr 4.000000e-07 reg 2.000000e+04 train accuracy: 0.322265 val accuracy: 0.333000
# lr 4.000000e-07 reg 2.100000e+04 train accuracy: 0.330122 val accuracy: 0.347000
# lr 4.000000e-07 reg 2.200000e+04 train accuracy: 0.328510 val accuracy: 0.345000
# lr 4.000000e-07 reg 2.300000e+04 train accuracy: 0.323265 val accuracy: 0.347000
# lr 4.000000e-07 reg 2.400000e+04 train accuracy: 0.336531 val accuracy: 0.341000
# lr 4.000000e-07 reg 2.500000e+04 train accuracy: 0.328429 val accuracy: 0.336000
# lr 5.000000e-07 reg 1.000000e+04 train accuracy: 0.324306 val accuracy: 0.341000
# lr 5.000000e-07 reg 1.100000e+04 train accuracy: 0.335755 val accuracy: 0.350000
# lr 5.000000e-07 reg 1.200000e+04 train accuracy: 0.335082 val accuracy: 0.340000
# lr 5.000000e-07 reg 1.300000e+04 train accuracy: 0.335694 val accuracy: 0.351000
# lr 5.000000e-07 reg 1.400000e+04 train accuracy: 0.333367 val accuracy: 0.341000
# lr 5.000000e-07 reg 1.500000e+04 train accuracy: 0.332143 val accuracy: 0.341000
# lr 5.000000e-07 reg 1.600000e+04 train accuracy: 0.333061 val accuracy: 0.338000
# lr 5.000000e-07 reg 1.700000e+04 train accuracy: 0.335796 val accuracy: 0.346000
# lr 5.000000e-07 reg 1.800000e+04 train accuracy: 0.336980 val accuracy: 0.343000
# lr 5.000000e-07 reg 1.900000e+04 train accuracy: 0.332469 val accuracy: 0.348000
# lr 5.000000e-07 reg 2.000000e+04 train accuracy: 0.330980 val accuracy: 0.344000
# lr 5.000000e-07 reg 2.100000e+04 train accuracy: 0.329490 val accuracy: 0.339000
# lr 5.000000e-07 reg 2.200000e+04 train accuracy: 0.327327 val accuracy: 0.344000
# lr 5.000000e-07 reg 2.300000e+04 train accuracy: 0.324653 val accuracy: 0.338000
# lr 5.000000e-07 reg 2.400000e+04 train accuracy: 0.336367 val accuracy: 0.353000
# lr 5.000000e-07 reg 2.500000e+04 train accuracy: 0.321980 val accuracy: 0.342000
# lr 6.000000e-07 reg 1.000000e+04 train accuracy: 0.337673 val accuracy: 0.344000
# lr 6.000000e-07 reg 1.100000e+04 train accuracy: 0.337939 val accuracy: 0.359000
# lr 6.000000e-07 reg 1.200000e+04 train accuracy: 0.346204 val accuracy: 0.346000
# lr 6.000000e-07 reg 1.300000e+04 train accuracy: 0.333306 val accuracy: 0.327000
# lr 6.000000e-07 reg 1.400000e+04 train accuracy: 0.344878 val accuracy: 0.356000
# lr 6.000000e-07 reg 1.500000e+04 train accuracy: 0.344408 val accuracy: 0.355000
# lr 6.000000e-07 reg 1.600000e+04 train accuracy: 0.337755 val accuracy: 0.350000
# lr 6.000000e-07 reg 1.700000e+04 train accuracy: 0.337286 val accuracy: 0.364000
# lr 6.000000e-07 reg 1.800000e+04 train accuracy: 0.334612 val accuracy: 0.348000
# lr 6.000000e-07 reg 1.900000e+04 train accuracy: 0.331347 val accuracy: 0.357000
# lr 6.000000e-07 reg 2.000000e+04 train accuracy: 0.324551 val accuracy: 0.325000
# lr 6.000000e-07 reg 2.100000e+04 train accuracy: 0.324061 val accuracy: 0.337000
# lr 6.000000e-07 reg 2.200000e+04 train accuracy: 0.329469 val accuracy: 0.344000
# lr 6.000000e-07 reg 2.300000e+04 train accuracy: 0.336939 val accuracy: 0.351000
# lr 6.000000e-07 reg 2.400000e+04 train accuracy: 0.328429 val accuracy: 0.337000
# lr 6.000000e-07 reg 2.500000e+04 train accuracy: 0.328184 val accuracy: 0.354000
# lr 7.000000e-07 reg 1.000000e+04 train accuracy: 0.340061 val accuracy: 0.348000
# lr 7.000000e-07 reg 1.100000e+04 train accuracy: 0.334857 val accuracy: 0.365000
# lr 7.000000e-07 reg 1.200000e+04 train accuracy: 0.343102 val accuracy: 0.354000
# lr 7.000000e-07 reg 1.300000e+04 train accuracy: 0.348878 val accuracy: 0.358000
# lr 7.000000e-07 reg 1.400000e+04 train accuracy: 0.343694 val accuracy: 0.374000
# lr 7.000000e-07 reg 1.500000e+04 train accuracy: 0.341776 val accuracy: 0.356000
# lr 7.000000e-07 reg 1.600000e+04 train accuracy: 0.344245 val accuracy: 0.360000
# lr 7.000000e-07 reg 1.700000e+04 train accuracy: 0.341490 val accuracy: 0.355000
# lr 7.000000e-07 reg 1.800000e+04 train accuracy: 0.323204 val accuracy: 0.337000
# lr 7.000000e-07 reg 1.900000e+04 train accuracy: 0.330735 val accuracy: 0.346000
# lr 7.000000e-07 reg 2.000000e+04 train accuracy: 0.333612 val accuracy: 0.353000
# lr 7.000000e-07 reg 2.100000e+04 train accuracy: 0.335245 val accuracy: 0.350000
# lr 7.000000e-07 reg 2.200000e+04 train accuracy: 0.334204 val accuracy: 0.341000
# lr 7.000000e-07 reg 2.300000e+04 train accuracy: 0.320102 val accuracy: 0.342000
# lr 7.000000e-07 reg 2.400000e+04 train accuracy: 0.322837 val accuracy: 0.333000
# lr 7.000000e-07 reg 2.500000e+04 train accuracy: 0.320020 val accuracy: 0.321000
# lr 8.000000e-07 reg 1.000000e+04 train accuracy: 0.348592 val accuracy: 0.363000
# lr 8.000000e-07 reg 1.100000e+04 train accuracy: 0.354306 val accuracy: 0.364000
# lr 8.000000e-07 reg 1.200000e+04 train accuracy: 0.337510 val accuracy: 0.357000
# lr 8.000000e-07 reg 1.300000e+04 train accuracy: 0.337388 val accuracy: 0.364000
# lr 8.000000e-07 reg 1.400000e+04 train accuracy: 0.332286 val accuracy: 0.352000
# lr 8.000000e-07 reg 1.500000e+04 train accuracy: 0.329306 val accuracy: 0.343000
# lr 8.000000e-07 reg 1.600000e+04 train accuracy: 0.341143 val accuracy: 0.347000
# lr 8.000000e-07 reg 1.700000e+04 train accuracy: 0.341204 val accuracy: 0.351000
# lr 8.000000e-07 reg 1.800000e+04 train accuracy: 0.339898 val accuracy: 0.350000
# lr 8.000000e-07 reg 1.900000e+04 train accuracy: 0.337755 val accuracy: 0.344000
# lr 8.000000e-07 reg 2.000000e+04 train accuracy: 0.324102 val accuracy: 0.326000
# lr 8.000000e-07 reg 2.100000e+04 train accuracy: 0.327449 val accuracy: 0.332000
# lr 8.000000e-07 reg 2.200000e+04 train accuracy: 0.332102 val accuracy: 0.345000
# lr 8.000000e-07 reg 2.300000e+04 train accuracy: 0.318959 val accuracy: 0.331000
# lr 8.000000e-07 reg 2.400000e+04 train accuracy: 0.328653 val accuracy: 0.333000
# lr 8.000000e-07 reg 2.500000e+04 train accuracy: 0.326571 val accuracy: 0.337000
# lr 9.000000e-07 reg 1.000000e+04 train accuracy: 0.350571 val accuracy: 0.357000
# lr 9.000000e-07 reg 1.100000e+04 train accuracy: 0.344898 val accuracy: 0.348000
# lr 9.000000e-07 reg 1.200000e+04 train accuracy: 0.341980 val accuracy: 0.348000
# lr 9.000000e-07 reg 1.300000e+04 train accuracy: 0.344653 val accuracy: 0.363000
# lr 9.000000e-07 reg 1.400000e+04 train accuracy: 0.349531 val accuracy: 0.354000
# lr 9.000000e-07 reg 1.500000e+04 train accuracy: 0.334122 val accuracy: 0.347000
# lr 9.000000e-07 reg 1.600000e+04 train accuracy: 0.328388 val accuracy: 0.338000
# lr 9.000000e-07 reg 1.700000e+04 train accuracy: 0.337571 val accuracy: 0.356000
# lr 9.000000e-07 reg 1.800000e+04 train accuracy: 0.327796 val accuracy: 0.342000
# lr 9.000000e-07 reg 1.900000e+04 train accuracy: 0.336714 val accuracy: 0.347000
# lr 9.000000e-07 reg 2.000000e+04 train accuracy: 0.330837 val accuracy: 0.336000
# lr 9.000000e-07 reg 2.100000e+04 train accuracy: 0.337714 val accuracy: 0.339000
# lr 9.000000e-07 reg 2.200000e+04 train accuracy: 0.327918 val accuracy: 0.337000
# lr 9.000000e-07 reg 2.300000e+04 train accuracy: 0.319714 val accuracy: 0.329000
# lr 9.000000e-07 reg 2.400000e+04 train accuracy: 0.308837 val accuracy: 0.324000
# lr 9.000000e-07 reg 2.500000e+04 train accuracy: 0.324551 val accuracy: 0.332000
# lr 1.000000e-06 reg 1.000000e+04 train accuracy: 0.350796 val accuracy: 0.368000
# lr 1.000000e-06 reg 1.100000e+04 train accuracy: 0.349367 val accuracy: 0.356000
# lr 1.000000e-06 reg 1.200000e+04 train accuracy: 0.346020 val accuracy: 0.344000
# lr 1.000000e-06 reg 1.300000e+04 train accuracy: 0.342347 val accuracy: 0.352000
# lr 1.000000e-06 reg 1.400000e+04 train accuracy: 0.339204 val accuracy: 0.351000
# lr 1.000000e-06 reg 1.500000e+04 train accuracy: 0.344592 val accuracy: 0.356000
# lr 1.000000e-06 reg 1.600000e+04 train accuracy: 0.334551 val accuracy: 0.343000
# lr 1.000000e-06 reg 1.700000e+04 train accuracy: 0.326163 val accuracy: 0.329000
# lr 1.000000e-06 reg 1.800000e+04 train accuracy: 0.331959 val accuracy: 0.350000
# lr 1.000000e-06 reg 1.900000e+04 train accuracy: 0.329776 val accuracy: 0.332000
# lr 1.000000e-06 reg 2.000000e+04 train accuracy: 0.317796 val accuracy: 0.329000
# lr 1.000000e-06 reg 2.100000e+04 train accuracy: 0.326776 val accuracy: 0.332000
# lr 1.000000e-06 reg 2.200000e+04 train accuracy: 0.313327 val accuracy: 0.330000
# lr 1.000000e-06 reg 2.300000e+04 train accuracy: 0.310102 val accuracy: 0.334000
# lr 1.000000e-06 reg 2.400000e+04 train accuracy: 0.323592 val accuracy: 0.333000
# lr 1.000000e-06 reg 2.500000e+04 train accuracy: 0.317265 val accuracy: 0.336000
# best validation accuracy achieved during cross-validation: 0.374000

# %%
# Visualize the cross-validation results
import math
import pdb

# pdb.set_trace()

x_scatter = [math.log10(x[0]) for x in results]
y_scatter = [math.log10(x[1]) for x in results]

# plot training accuracy
marker_size = 100
colors = [results[x][0] for x in results]
plt.subplot(2, 1, 1)
plt.tight_layout(pad=3)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap=plt.cm.coolwarm)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')

# plot validation accuracy
colors = [results[x][1] for x in results] # default size of markers is 20
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap=plt.cm.coolwarm)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.show()

# %%
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('Softmax classifier on raw pixels final test set accuracy: %f' % test_accuracy)
# Out:
# Softmax classifier on raw pixels final test set accuracy: 0.355000

# %%
# Save best softmax model
best_softmax.save("best_softmax.npy")
# Out:
# best_softmax.npy saved.

# %%
# Visualize the learned weights for each class.
# Depending on your choice of learning rate and regularization strength, these may
# or may not be nice to look at.
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)
w_min, w_max = np.min(w), np.max(w)
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)

    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])

# %% [markdown]
# **Inline question 3**
#
# Describe what your visualized Softmax classifier weights look like, and offer a brief explanation for why they look the way they do.
#
# $\color{blue}{\textit Your Answer:}$ *fill this in*
#
# 直观上感觉非常得模糊，car和马还是能看出来有点轮廓的，其他的就显得非常杂乱无章。在准确率只有36%左右的情况下，我不觉得softmax学到了太多的特征。我认为softmax或许效果不好。又或许我的代码学习的次数和数量不高。

# %% [markdown]
# **Inline Question 4** - *True or False*
#
# Suppose the overall training loss is defined as the sum of the per-datapoint loss over all training examples. It is possible to add a new datapoint to a training set that would change the softmax loss, but leave the SVM loss unchanged.
#
# $\color{blue}{\textit Your Answer:}$
#
#
# $\color{blue}{\textit Your Explanation:}$
#
# 正确/错误的，我认为对于softmax来说是有影响的，毕竟是连续的，我的一个data的添加一定会得到一些改变；但是对于SVM如果加入的data使得得到的部分是 $s_{j}-s_{y_j}+Δ$ 部分则会改变，如果得到的是0，则不会改变！
